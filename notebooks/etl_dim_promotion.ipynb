# %%
import pandas as pd
from connection import connect

# %%
#connection
SCHEMA='sales'
co_oltp,etl_conn,etl_conn_or=connect(SCHEMA)
# Out:
# ['sales_person_quota_history', 'country_region_currency', 'sales_reason', 'credit_card', 'sales_tax_rate', 'currency', 'sales_territory', 'currency_rate', 'sales_territory_history', 'customer', 'shopping_cart_item', 'person_credit_card', 'special_offer', 'special_offer_product', 'sales_order_header_sales_reason', 'sales_order_detail', 'sales_order_header', 'sales_person', 'store']

# %% [markdown]
# ## Extract

# %%
#extract DimProductCategory


# from deep_translator import GoogleTranslator

dim_promotion=pd.read_sql_table('special_offer',co_oltp,schema=SCHEMA)
# dim_promotion
# dim_promotion

# %% [markdown]
# ## Transform

# %%
from deep_translator import GoogleTranslator

dim_promotion=dim_promotion.rename(columns={
    'special_offer_id':'promotion_alternate_key',
    'description':'english_promotion_name',
    'type':'english_promotion_type',
    'category':'english_promotion_category',
    })


dim_promotion.drop(['rowguid','modified_date'],inplace=True,axis=1)

dim_promotion['spanish_promotion_name']=dim_promotion['english_promotion_name'].apply(lambda x : GoogleTranslator(source='en',target='es').translate(x) if x is not None else None )
dim_promotion['french_promotion_name']=dim_promotion['english_promotion_name'].apply(lambda x : GoogleTranslator(source='en',target='fr').translate(x) if x is not None else None )
dim_promotion['spanish_promotion_category']=dim_promotion['english_promotion_category'].apply(lambda x : GoogleTranslator(source='en',target='es').translate(x) if x is not None else None )
dim_promotion['french_promotion_category']=dim_promotion['english_promotion_category'].apply(lambda x : GoogleTranslator(source='en',target='fr').translate(x) if x is not None else None )
dim_promotion['spanish_promotion_type']=dim_promotion['english_promotion_type'].apply(lambda x : GoogleTranslator(source='en',target='es').translate(x) if x is not None else None )
dim_promotion['french_promotion_type']=dim_promotion['english_promotion_type'].apply(lambda x : GoogleTranslator(source='en',target='fr').translate(x) if x is not None else None )



# dim_promotion_copy['start_date']=dim_promotion_copy['start_date']-pd.DateOffset(months=5,days=2)
# dim_promotion_copy['end_date']=dim_promotion_copy['end_date']-pd.DateOffset(months=5,days=2)

dim_promotion
# Out:
#     promotion_alternate_key              english_promotion_name  discount_pct  \
# 0                         1                         No Discount          0.00
# 1                         2            Volume Discount 11 to 14          0.02
# 2                         3            Volume Discount 15 to 24          0.05
# 3                         4            Volume Discount 25 to 40          0.10
# 4                         5            Volume Discount 41 to 60          0.15
# 5                         6             Volume Discount over 60          0.20
# 6                         7         Mountain-100 Clearance Sale          0.35
# 7                         8          Sport Helmet Discount-2002          0.10
# 8                         9                  Road-650 Overstock          0.30
# 9                        10                  Mountain Tire Sale          0.50
# 10                       11          Sport Helmet Discount-2003          0.15
# 11                       12                  LL Road Frame Sale          0.35
# 12                       13              Touring-3000 Promotion          0.15
# 13                       14              Touring-1000 Promotion          0.20
# 14                       15               Half-Price Pedal Sale          0.50
# 15                       16  Mountain-500 Silver Clearance Sale          0.40
#
#    english_promotion_type english_promotion_category  \
# 0             No Discount                No Discount
# 1         Volume Discount                   Reseller
# 2         Volume Discount                   Reseller
# 3         Volume Discount                   Reseller
# 4         Volume Discount                   Reseller
# 5         Volume Discount                   Reseller
# 6    Discontinued Product                   Reseller
# 7       Seasonal Discount                   Reseller
# 8        Excess Inventory                   Reseller
# 9        Excess Inventory                   Customer
# 10      Seasonal Discount                   Reseller
# 11       Excess Inventory                   Reseller
# 12            New Product                   Reseller
# 13            New Product                   Reseller
# 14      Seasonal Discount                   Customer
# 15   Discontinued Product                   Reseller
#
#                   start_date                  end_date  min_qty  max_qty  \
# 0  2011-05-01 00:00:00+00:00 2014-11-30 00:00:00+00:00        0      NaN
# 1  2011-05-31 00:00:00+00:00 2014-05-30 00:00:00+00:00       11     14.0
# 2  2011-05-31 00:00:00+00:00 2014-05-30 00:00:00+00:00       15     24.0
# 3  2011-05-31 00:00:00+00:00 2014-05-30 00:00:00+00:00       25     40.0
# 4  2011-05-31 00:00:00+00:00 2014-05-30 00:00:00+00:00       41     60.0
# 5  2011-05-31 00:00:00+00:00 2014-05-30 00:00:00+00:00       61      NaN
# 6  2012-04-13 00:00:00+00:00 2012-05-29 00:00:00+00:00        0      NaN
# 7  2012-05-30 00:00:00+00:00 2012-06-29 00:00:00+00:00        0      NaN
# 8  2012-05-30 00:00:00+00:00 2012-07-30 00:00:00+00:00        0      NaN
# 9  2013-05-14 00:00:00+00:00 2013-07-29 00:00:00+00:00        0      NaN
# 10 2013-05-30 00:00:00+00:00 2013-06-29 00:00:00+00:00        0      NaN
# 11 2013-05-30 00:00:00+00:00 2013-07-14 00:00:00+00:00        0      NaN
# 12 2013-05-30 00:00:00+00:00 2013-08-29 00:00:00+00:00        0      NaN
# 13 2013-05-30 00:00:00+00:00 2013-08-29 00:00:00+00:00        0      NaN
# 14 2013-07-14 00:00:00+00:00 2013-08-14 00:00:00+00:00        0      NaN
# 15 2014-03-31 00:00:00+00:00 2014-05-30 00:00:00+00:00        0      NaN
#
#                          spanish_promotion_name  \
# 0                                 Sin descuento
# 1                 Descuento por volumen 11 a 14
# 2                 Descuento por volumen 15 a 24
# 3                 Descuento por volumen 25 a 40
# 4                 Descuento por volumen 41 a 60
# 5             Descuento por volumen mayor de 60
# 6         Oferta de liquidación de Mountain-100
# 7             Descuento en casco deportivo-2002
# 8           Carretera-650 Exceso de existencias
# 9                Venta de neumáticos de montaña
# 10            Descuento en casco deportivo-2003
# 11             Venta de cuadros de carretera LL
# 12                       Promoción Touring-3000
# 13                       Promoción Touring-1000
# 14          Oferta de pedales a mitad de precio
# 15  Oferta de liquidación de plata Mountain-500
#
#                        french_promotion_name spanish_promotion_category  \
# 0                           Pas de réduction              Sin descuento
# 1                  Remise sur volume 11 à 14                 Revendedor
# 2                  Remise sur volume 15 à 24                 Revendedor
# 3                  Remise sur volume 25 à 40                 Revendedor
# 4                  Remise sur volume 41 à 60                 Revendedor
# 5          Remise sur volume supérieure à 60                 Revendedor
# 6          Vente de liquidation Mountain-100                 Revendedor
# 7       Remise sur les casques de sport-2002                 Revendedor
# 8                         Route 650 Surstock                 Revendedor
# 9                 Vente de pneus de montagne                    Cliente
# 10      Remise sur les casques de sport-2003                 Revendedor
# 11               Vente de cadres de route LL                 Revendedor
# 12                    Promotion Touring-3000                 Revendedor
# 13                    Promotion Touring-1000                 Revendedor
# 14            Vente de pédales à moitié prix                    Cliente
# 15  Vente de liquidation Mountain-500 Argent                 Revendedor
#
#    french_promotion_category  spanish_promotion_type    french_promotion_type
# 0           Pas de réduction           Sin descuento         Pas de réduction
# 1                  Revendeur   Descuento por volumen        Remise sur volume
# 2                  Revendeur   Descuento por volumen        Remise sur volume
# 3                  Revendeur   Descuento por volumen        Remise sur volume
# 4                  Revendeur   Descuento por volumen        Remise sur volume
# 5                  Revendeur   Descuento por volumen        Remise sur volume
# 6                  Revendeur  Producto descatalogado        Produit abandonné
# 7                  Revendeur  Descuento de temporada       Remise saisonnière
# 8                  Revendeur    Exceso de inventario  Inventaire excédentaire
# 9                     Client    Exceso de inventario  Inventaire excédentaire
# 10                 Revendeur  Descuento de temporada       Remise saisonnière
# 11                 Revendeur    Exceso de inventario  Inventaire excédentaire
# 12                 Revendeur          Nuevo producto          Nouveau produit
# 13                 Revendeur          Nuevo producto          Nouveau produit
# 14                    Client  Descuento de temporada       Remise saisonnière
# 15                 Revendeur  Producto descatalogado        Produit abandonné

# %% [markdown]
# ## Load

# %%
dim_promotion.to_sql('dim_promotion', etl_conn, if_exists='append',index=False)
# Out:
# 16
