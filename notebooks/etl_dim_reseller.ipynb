# %%
import pandas as pd
import xml.etree.ElementTree as ET
from sqlalchemy import text
from connection import connect

# %%
co_oltp, etl_conn, etl_conn_or = connect()

# %% [markdown]
# # Extract

# %%
query_reseller = text("""
-- CTE para pre-agregar información de clientes y órdenes
WITH ResellerCustomerInfo AS (
    SELECT
        c.store_id,
        MIN(c.account_number) AS reseller_alternate_key,
        EXTRACT(YEAR FROM MIN(soh.order_date)) AS first_order_year,
        EXTRACT(YEAR FROM MAX(soh.order_date)) AS last_order_year,
        EXTRACT(MONTH FROM MAX(soh.order_date)) AS order_month,
        '0' as order_frequency
    FROM sales.customer AS c
    LEFT JOIN sales.sales_order_header AS soh ON c.customer_id = soh.customer_id
    WHERE c.store_id IS NOT NULL
    GROUP BY c.store_id
),
-- CTE para seleccionar una única dirección por tienda (Revendedor)
RankedAddresses AS (
    SELECT
        bea.business_entity_id,
        a.address_line_1,
        a.address_line_2,
        a.city,
        a.postal_code,
        st.name AS state_province_name,
        cr.name AS country_region_name,
        -- Rankeamos las direcciones por tipo, priorizando 'Main Office'
        ROW_NUMBER() OVER(
            PARTITION BY bea.business_entity_id
            ORDER BY
                CASE
                    WHEN at.name = 'Main Office' THEN 1
                    ELSE 99
                END
        ) as rn_addr
    FROM person.business_entity_address AS bea
    JOIN person.address AS a ON bea.address_id = a.address_id
    JOIN person.address_type AS at ON bea.address_type_id = at.address_type_id
    JOIN person.state_province AS st ON a.state_province_id = st.state_province_id
    JOIN person.country_region AS cr ON st.country_region_code = cr.country_region_code
),
-- CTE para seleccionar un unico teléfono por tienda, a través del contacto
RankedContacts AS (
    SELECT
        bec.business_entity_id, -- El ID de la tienda (Store)
        pp.phone_number,
        -- Rankeamos los contactos
        ROW_NUMBER() OVER(
            PARTITION BY bec.business_entity_id
            ORDER BY bec.contact_type_id
        ) as rn_contact
    FROM person.business_entity_contact AS bec
    JOIN person.person AS p ON bec.person_id = p.business_entity_id
    JOIN person.person_phone AS pp ON p.business_entity_id = pp.business_entity_id
)
SELECT
    s.business_entity_id,
    cus.account_number AS reseller_alternate_key,
    s.name AS reseller_name,
    s.demographics,

    -- Datos de la dirección desde la CTE de direcciones
    ra.address_line_1 AS address_line1,
    ra.address_line_2 AS address_line2,
    ra.city,
    ra.postal_code,
    ra.state_province_name,
    ra.country_region_name,

    -- Datos del cliente pre-agregados desde la primera CTE
    rci.first_order_year,
    rci.last_order_year,
    rci.order_month,
    rci.order_frequency,

    -- El teléfono desde la CTE de contactos
    rc.phone_number AS phone

FROM sales.store AS s

LEFT JOIN ResellerCustomerInfo AS rci ON s.business_entity_id = rci.store_id

LEFT JOIN RankedAddresses AS ra
    ON s.business_entity_id = ra.business_entity_id
    AND ra.rn_addr = 1

LEFT JOIN RankedContacts AS rc
    ON s.business_entity_id = rc.business_entity_id
    AND rc.rn_contact = 1

LEFT JOIN sales.customer as cus
    ON cus.store_id = s.business_entity_id
    AND cus.person_id IS NULL;
""")

df_reseller = pd.read_sql(query_reseller, co_oltp)
print(f"Registros extraidos: {len(df_reseller)}")
df_reseller
# Out:
# Registros extraidos: 701
#      business_entity_id reseller_alternate_key                  reseller_name  \
# 0                   934             AW00000001                   A Bike Store
# 1                  1028             AW00000002             Progressive Sports
# 2                   642             AW00000003       Advanced Bike Components
# 3                   932             AW00000004          Modular Cycle Systems
# 4                  1026             AW00000005     Metropolitan Sports Supply
# ..                  ...                    ...                            ...
# 696                1032             AW00000697               Brakes and Gears
# 697                 640             AW00000698          Western Bike Supplies
# 698                 842             AW00000699     Sensational Discount Store
# 699                1030             AW00000700  Underglaze and Finish Company
# 700                 844             AW00000701                   Future Bikes
#
#                                           demographics  \
# 0    <StoreSurvey xmlns="http://schemas.microsoft.c...
# 1    <StoreSurvey xmlns="http://schemas.microsoft.c...
# 2    <StoreSurvey xmlns="http://schemas.microsoft.c...
# 3    <StoreSurvey xmlns="http://schemas.microsoft.c...
# 4    <StoreSurvey xmlns="http://schemas.microsoft.c...
# ..                                                 ...
# 696  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 697  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 698  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 699  <StoreSurvey xmlns="http://schemas.microsoft.c...
# 700  <StoreSurvey xmlns="http://schemas.microsoft.c...
#
#                           address_line1 address_line2        city postal_code  \
# 0                    2251 Elliot Avenue          None     Seattle       98104
# 1                      3207 S Grady Way          None      Renton       98055
# 2                 12345 Sterling Avenue          None      Irving       75061
# 3                 800 Interchange Blvd.    Suite 2501      Austin       78701
# 4             482505 Warm Springs Blvd.          None     Fremont       94536
# ..                                  ...           ...         ...         ...
# 696                    9927 N. Main St.          None      Tooele       84074
# 697                         566 S. Main          None  Cedar City       84720
# 698             6333 Cloverleaf Parkway          None  Kannapolis       28081
# 699           8520 University City Blvd          None   Charlotte       28202
# 700  67255 - 8th Street N.E., Suite 350          None     Calgary     T2P 2G8
#
#     state_province_name country_region_name  first_order_year  \
# 0            Washington       United States            2011.0
# 1            Washington       United States            2012.0
# 2                 Texas       United States            2011.0
# 3                 Texas       United States            2012.0
# 4            California       United States            2012.0
# ..                  ...                 ...               ...
# 696                Utah       United States            2011.0
# 697                Utah       United States            2012.0
# 698      North Carolina       United States            2014.0
# 699      North Carolina       United States            2013.0
# 700             Alberta              Canada            2012.0
#
#      last_order_year  order_month order_frequency         phone
# 0             2012.0          3.0               0  245-555-0173
# 1             2014.0          3.0               0  230-555-0100
# 2             2014.0          5.0               0  279-555-0130
# 3             2014.0          3.0               0  710-555-0173
# 4             2014.0          5.0               0  755-555-0100
# ..               ...          ...             ...           ...
# 696           2014.0          3.0               0  774-555-0133
# 697           2013.0          2.0               0  944-555-0148
# 698           2014.0          1.0               0  716-555-0123
# 699           2014.0          3.0               0  703-555-0158
# 700           2014.0          5.0               0  674-555-0188
#
# [701 rows x 15 columns]

# %%
df_reseller.columns
# Out:
# Index(['business_entity_id', 'reseller_name', 'demographics', 'address_line1',
#        'address_line2', 'city', 'postal_code', 'state_province_name',
#        'country_region_name', 'reseller_alternate_key', 'first_order_year',
#        'last_order_year', 'order_month', 'order_frequency', 'phone'],
#       dtype='object')

# %% [markdown]
# # Transform

# %%
def parse_store_demographics(xml_string):
    if pd.isna(xml_string):
        return {}

    try:
        root = ET.fromstring(xml_string)
        ns = {'ns': root.tag.split('}')[0].strip('{')}

        def namespace_find(tag):
            el = root.find(f'ns:{tag}', ns)
            return el.text if el is not None else None


        result = {
            'annual_sales': namespace_find('AnnualSales'),
            'annual_revenue': namespace_find('AnnualRevenue'),
            'bank_name': namespace_find('BankName'),
            'business_type': namespace_find('BusinessType'),
            'year_opened': namespace_find('YearOpened'),
            'product_line': namespace_find('Specialty'),
            'number_employees': namespace_find('NumberEmployees'),
            'min_payment_type': None,
            'min_payment_amount': None,
        }
        return result

    except Exception as e:
        return {}

# %%
demographics_df = df_reseller['demographics'].apply(parse_store_demographics).apply(pd.Series)

# %%
tipos = demographics_df['business_type'].unique()
print(tipos)
# Out:
# ['BM' 'BS' 'OS']

# %%
# Mapeando el tipo de negocio
business_type_map = {
    'BM': 'Warehouse',
    'OS': 'Value Added Reseller',
    'BS': 'Specialty Bike Shop'
}

demographics_df['business_type'] = demographics_df['business_type'].map(business_type_map)

print(demographics_df['business_type'].value_counts())
# Out:
# business_type
# Warehouse               238
# Value Added Reseller    232
# Specialty Bike Shop     231
# Name: count, dtype: int64

# %%
df_with_demographics = pd.concat([df_reseller.drop('demographics', axis=1), demographics_df], axis=1)
df_with_demographics
# Out:
#      business_entity_id reseller_alternate_key                  reseller_name  \
# 0                   934             AW00000001                   A Bike Store
# 1                  1028             AW00000002             Progressive Sports
# 2                   642             AW00000003       Advanced Bike Components
# 3                   932             AW00000004          Modular Cycle Systems
# 4                  1026             AW00000005     Metropolitan Sports Supply
# ..                  ...                    ...                            ...
# 696                1032             AW00000697               Brakes and Gears
# 697                 640             AW00000698          Western Bike Supplies
# 698                 842             AW00000699     Sensational Discount Store
# 699                1030             AW00000700  Underglaze and Finish Company
# 700                 844             AW00000701                   Future Bikes
#
#                           address_line1 address_line2        city postal_code  \
# 0                    2251 Elliot Avenue          None     Seattle       98104
# 1                      3207 S Grady Way          None      Renton       98055
# 2                 12345 Sterling Avenue          None      Irving       75061
# 3                 800 Interchange Blvd.    Suite 2501      Austin       78701
# 4             482505 Warm Springs Blvd.          None     Fremont       94536
# ..                                  ...           ...         ...         ...
# 696                    9927 N. Main St.          None      Tooele       84074
# 697                         566 S. Main          None  Cedar City       84720
# 698             6333 Cloverleaf Parkway          None  Kannapolis       28081
# 699           8520 University City Blvd          None   Charlotte       28202
# 700  67255 - 8th Street N.E., Suite 350          None     Calgary     T2P 2G8
#
#     state_province_name country_region_name  first_order_year  ...  \
# 0            Washington       United States            2011.0  ...
# 1            Washington       United States            2012.0  ...
# 2                 Texas       United States            2011.0  ...
# 3                 Texas       United States            2012.0  ...
# 4            California       United States            2012.0  ...
# ..                  ...                 ...               ...  ...
# 696                Utah       United States            2011.0  ...
# 697                Utah       United States            2012.0  ...
# 698      North Carolina       United States            2014.0  ...
# 699      North Carolina       United States            2013.0  ...
# 700             Alberta              Canada            2012.0  ...
#
#             phone  annual_sales annual_revenue               bank_name  \
# 0    245-555-0173        300000          30000      International Bank
# 1    230-555-0100        800000          80000  International Security
# 2    279-555-0130       1500000         150000   Primary International
# 3    710-555-0173        300000          30000         United Security
# 4    755-555-0100        800000          80000  Primary Bank & Reserve
# ..            ...           ...            ...                     ...
# 696  774-555-0133        800000          80000         United Security
# 697  944-555-0148       1500000         150000  Primary Bank & Reserve
# 698  716-555-0123       3000000         300000           Guardian Bank
# 699  703-555-0158        800000          80000        Reserve Security
# 700  674-555-0188       3000000         300000           Guardian Bank
#
#             business_type year_opened product_line number_employees  \
# 0               Warehouse        1970         Road                2
# 1     Specialty Bike Shop        1972     Mountain               10
# 2    Value Added Reseller        1974         Road               40
# 3               Warehouse        1976         Road                5
# 4     Specialty Bike Shop        1978         Road               13
# ..                    ...         ...          ...              ...
# 696             Warehouse        1988     Mountain               12
# 697   Specialty Bike Shop        1994         Road               48
# 698  Value Added Reseller        1987         Road               80
# 699             Warehouse        1993         Road               11
# 700  Value Added Reseller        1992         Road               81
#
#     min_payment_type min_payment_amount
# 0               None               None
# 1               None               None
# 2               None               None
# 3               None               None
# 4               None               None
# ..               ...                ...
# 696             None               None
# 697             None               None
# 698             None               None
# 699             None               None
# 700             None               None
#
# [701 rows x 23 columns]

# %%
df_with_demographics
# Out:
#      business_entity_id reseller_alternate_key                  reseller_name  \
# 0                   934             AW00000001                   A Bike Store
# 1                  1028             AW00000002             Progressive Sports
# 2                   642             AW00000003       Advanced Bike Components
# 3                   932             AW00000004          Modular Cycle Systems
# 4                  1026             AW00000005     Metropolitan Sports Supply
# ..                  ...                    ...                            ...
# 696                1032             AW00000697               Brakes and Gears
# 697                 640             AW00000698          Western Bike Supplies
# 698                 842             AW00000699     Sensational Discount Store
# 699                1030             AW00000700  Underglaze and Finish Company
# 700                 844             AW00000701                   Future Bikes
#
#                           address_line1 address_line2        city postal_code  \
# 0                    2251 Elliot Avenue          None     Seattle       98104
# 1                      3207 S Grady Way          None      Renton       98055
# 2                 12345 Sterling Avenue          None      Irving       75061
# 3                 800 Interchange Blvd.    Suite 2501      Austin       78701
# 4             482505 Warm Springs Blvd.          None     Fremont       94536
# ..                                  ...           ...         ...         ...
# 696                    9927 N. Main St.          None      Tooele       84074
# 697                         566 S. Main          None  Cedar City       84720
# 698             6333 Cloverleaf Parkway          None  Kannapolis       28081
# 699           8520 University City Blvd          None   Charlotte       28202
# 700  67255 - 8th Street N.E., Suite 350          None     Calgary     T2P 2G8
#
#     state_province_name country_region_name  first_order_year  ...  \
# 0            Washington       United States            2011.0  ...
# 1            Washington       United States            2012.0  ...
# 2                 Texas       United States            2011.0  ...
# 3                 Texas       United States            2012.0  ...
# 4            California       United States            2012.0  ...
# ..                  ...                 ...               ...  ...
# 696                Utah       United States            2011.0  ...
# 697                Utah       United States            2012.0  ...
# 698      North Carolina       United States            2014.0  ...
# 699      North Carolina       United States            2013.0  ...
# 700             Alberta              Canada            2012.0  ...
#
#             phone  annual_sales annual_revenue               bank_name  \
# 0    245-555-0173        300000          30000      International Bank
# 1    230-555-0100        800000          80000  International Security
# 2    279-555-0130       1500000         150000   Primary International
# 3    710-555-0173        300000          30000         United Security
# 4    755-555-0100        800000          80000  Primary Bank & Reserve
# ..            ...           ...            ...                     ...
# 696  774-555-0133        800000          80000         United Security
# 697  944-555-0148       1500000         150000  Primary Bank & Reserve
# 698  716-555-0123       3000000         300000           Guardian Bank
# 699  703-555-0158        800000          80000        Reserve Security
# 700  674-555-0188       3000000         300000           Guardian Bank
#
#             business_type year_opened product_line number_employees  \
# 0               Warehouse        1970         Road                2
# 1     Specialty Bike Shop        1972     Mountain               10
# 2    Value Added Reseller        1974         Road               40
# 3               Warehouse        1976         Road                5
# 4     Specialty Bike Shop        1978         Road               13
# ..                    ...         ...          ...              ...
# 696             Warehouse        1988     Mountain               12
# 697   Specialty Bike Shop        1994         Road               48
# 698  Value Added Reseller        1987         Road               80
# 699             Warehouse        1993         Road               11
# 700  Value Added Reseller        1992         Road               81
#
#     min_payment_type min_payment_amount
# 0               None               None
# 1               None               None
# 2               None               None
# 3               None               None
# 4               None               None
# ..               ...                ...
# 696             None               None
# 697             None               None
# 698             None               None
# 699             None               None
# 700             None               None
#
# [701 rows x 23 columns]

# %%
# Vincula con DimGeography
df_geo_with_keys = pd.read_sql(
    text("""
        SELECT geography_key, city, postal_code, state_province_name, english_country_region_name as country_region_name
        FROM dim_geography;
    """),
    etl_conn
)

df_reseller_linked = pd.merge(
    df_with_demographics,
    df_geo_with_keys,
    on=['city', 'postal_code', 'state_province_name', 'country_region_name'],
    how='left'
)

# %%
print("Despues del merge con DimGeography:", df_reseller_linked.shape)
df_reseller_linked
# Out:
# Despues del merge con DimGeography: (701, 24)
#      business_entity_id reseller_alternate_key                  reseller_name  \
# 0                   934             AW00000001                   A Bike Store
# 1                  1028             AW00000002             Progressive Sports
# 2                   642             AW00000003       Advanced Bike Components
# 3                   932             AW00000004          Modular Cycle Systems
# 4                  1026             AW00000005     Metropolitan Sports Supply
# ..                  ...                    ...                            ...
# 696                1032             AW00000697               Brakes and Gears
# 697                 640             AW00000698          Western Bike Supplies
# 698                 842             AW00000699     Sensational Discount Store
# 699                1030             AW00000700  Underglaze and Finish Company
# 700                 844             AW00000701                   Future Bikes
#
#                           address_line1 address_line2        city postal_code  \
# 0                    2251 Elliot Avenue          None     Seattle       98104
# 1                      3207 S Grady Way          None      Renton       98055
# 2                 12345 Sterling Avenue          None      Irving       75061
# 3                 800 Interchange Blvd.    Suite 2501      Austin       78701
# 4             482505 Warm Springs Blvd.          None     Fremont       94536
# ..                                  ...           ...         ...         ...
# 696                    9927 N. Main St.          None      Tooele       84074
# 697                         566 S. Main          None  Cedar City       84720
# 698             6333 Cloverleaf Parkway          None  Kannapolis       28081
# 699           8520 University City Blvd          None   Charlotte       28202
# 700  67255 - 8th Street N.E., Suite 350          None     Calgary     T2P 2G8
#
#     state_province_name country_region_name  first_order_year  ...  \
# 0            Washington       United States            2011.0  ...
# 1            Washington       United States            2012.0  ...
# 2                 Texas       United States            2011.0  ...
# 3                 Texas       United States            2012.0  ...
# 4            California       United States            2012.0  ...
# ..                  ...                 ...               ...  ...
# 696                Utah       United States            2011.0  ...
# 697                Utah       United States            2012.0  ...
# 698      North Carolina       United States            2014.0  ...
# 699      North Carolina       United States            2013.0  ...
# 700             Alberta              Canada            2012.0  ...
#
#      annual_sales  annual_revenue               bank_name  \
# 0          300000           30000      International Bank
# 1          800000           80000  International Security
# 2         1500000          150000   Primary International
# 3          300000           30000         United Security
# 4          800000           80000  Primary Bank & Reserve
# ..            ...             ...                     ...
# 696        800000           80000         United Security
# 697       1500000          150000  Primary Bank & Reserve
# 698       3000000          300000           Guardian Bank
# 699        800000           80000        Reserve Security
# 700       3000000          300000           Guardian Bank
#
#             business_type year_opened product_line number_employees  \
# 0               Warehouse        1970         Road                2
# 1     Specialty Bike Shop        1972     Mountain               10
# 2    Value Added Reseller        1974         Road               40
# 3               Warehouse        1976         Road                5
# 4     Specialty Bike Shop        1978         Road               13
# ..                    ...         ...          ...              ...
# 696             Warehouse        1988     Mountain               12
# 697   Specialty Bike Shop        1994         Road               48
# 698  Value Added Reseller        1987         Road               80
# 699             Warehouse        1993         Road               11
# 700  Value Added Reseller        1992         Road               81
#
#     min_payment_type min_payment_amount geography_key
# 0               None               None            18
# 1               None               None           210
# 2               None               None           219
# 3               None               None           209
# 4               None               None           654
# ..               ...                ...           ...
# 696             None               None           391
# 697             None               None           649
# 698             None               None           263
# 699             None               None           313
# 700             None               None            17
#
# [701 rows x 24 columns]

# %%
# Limpia valores
df_reseller_linked['business_type'] = df_reseller_linked['business_type'].fillna('Unknown')
df_reseller_linked['product_line'] = df_reseller_linked['product_line'].fillna('None')

# %%
# Columnas finales segun DimReseller del DW
# se quito account_number recordad
final_columns = [
    'geography_key', 'reseller_alternate_key', 'phone', 'business_type',
    'reseller_name', 'number_employees', 'order_frequency', 'order_month',
    'first_order_year', 'last_order_year', 'product_line', 'address_line1',
    'address_line2', 'annual_sales', 'bank_name', 'min_payment_type',
    'min_payment_amount', 'annual_revenue', 'year_opened'
]

df_to_load = df_reseller_linked[final_columns]

# %%
df_to_load
# Out:
#      geography_key reseller_alternate_key         phone         business_type  \
# 0               18             AW00000001  245-555-0173             Warehouse
# 1              210             AW00000002  230-555-0100   Specialty Bike Shop
# 2              219             AW00000003  279-555-0130  Value Added Reseller
# 3              209             AW00000004  710-555-0173             Warehouse
# 4              654             AW00000005  755-555-0100   Specialty Bike Shop
# ..             ...                    ...           ...                   ...
# 696            391             AW00000697  774-555-0133             Warehouse
# 697            649             AW00000698  944-555-0148   Specialty Bike Shop
# 698            263             AW00000699  716-555-0123  Value Added Reseller
# 699            313             AW00000700  703-555-0158             Warehouse
# 700             17             AW00000701  674-555-0188  Value Added Reseller
#
#                      reseller_name number_employees order_frequency  \
# 0                     A Bike Store                2               0
# 1               Progressive Sports               10               0
# 2         Advanced Bike Components               40               0
# 3            Modular Cycle Systems                5               0
# 4       Metropolitan Sports Supply               13               0
# ..                             ...              ...             ...
# 696               Brakes and Gears               12               0
# 697          Western Bike Supplies               48               0
# 698     Sensational Discount Store               80               0
# 699  Underglaze and Finish Company               11               0
# 700                   Future Bikes               81               0
#
#      order_month  first_order_year  last_order_year product_line  \
# 0            3.0            2011.0           2012.0         Road
# 1            3.0            2012.0           2014.0     Mountain
# 2            5.0            2011.0           2014.0         Road
# 3            3.0            2012.0           2014.0         Road
# 4            5.0            2012.0           2014.0         Road
# ..           ...               ...              ...          ...
# 696          3.0            2011.0           2014.0     Mountain
# 697          2.0            2012.0           2013.0         Road
# 698          1.0            2014.0           2014.0         Road
# 699          3.0            2013.0           2014.0         Road
# 700          5.0            2012.0           2014.0         Road
#
#                           address_line1 address_line2 annual_sales  \
# 0                    2251 Elliot Avenue          None       300000
# 1                      3207 S Grady Way          None       800000
# 2                 12345 Sterling Avenue          None      1500000
# 3                 800 Interchange Blvd.    Suite 2501       300000
# 4             482505 Warm Springs Blvd.          None       800000
# ..                                  ...           ...          ...
# 696                    9927 N. Main St.          None       800000
# 697                         566 S. Main          None      1500000
# 698             6333 Cloverleaf Parkway          None      3000000
# 699           8520 University City Blvd          None       800000
# 700  67255 - 8th Street N.E., Suite 350          None      3000000
#
#                   bank_name min_payment_type min_payment_amount  \
# 0        International Bank             None               None
# 1    International Security             None               None
# 2     Primary International             None               None
# 3           United Security             None               None
# 4    Primary Bank & Reserve             None               None
# ..                      ...              ...                ...
# 696         United Security             None               None
# 697  Primary Bank & Reserve             None               None
# 698           Guardian Bank             None               None
# 699        Reserve Security             None               None
# 700           Guardian Bank             None               None
#
#     annual_revenue year_opened
# 0            30000        1970
# 1            80000        1972
# 2           150000        1974
# 3            30000        1976
# 4            80000        1978
# ..             ...         ...
# 696          80000        1988
# 697         150000        1994
# 698         300000        1987
# 699          80000        1993
# 700         300000        1992
#
# [701 rows x 19 columns]

# %% [markdown]
# # Load

# %%
df_to_load.to_sql(
    'dim_reseller',
    etl_conn,
    schema='dw',
    if_exists='append',
    index=False
)
# Out:
# 701

# %%
# RECORDAR QUITAR ACCOUNT NUMBER DE LA ESTRUCTURA
